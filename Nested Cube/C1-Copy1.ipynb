# %% [markdown]
# ## Analyzing the block $C_1$ for the Cube

# %%
load("../util.sage")

# %%
C1 = load('blocks/linear_block_1')

# %%
# simplify the expression of each block input
C1 = C1.apply_map(lambda x: x.simplify_real().combine()); show(C1)
# Out:
# [                                                                                                                                     24*c - 1/12*sqrt(3) - 3/8*sqrt(2) - 3/4       24*c - 1/3*(sqrt(3)*t + sqrt(3))/(t^3 + 3*t^2 + 3*t + 1) - 3*(t + 3)/(3*t^2 + 2*t + 3)^(3/2) + 3*(t - 3)/(3*t^2 - 2*t + 3)^(3/2) - 1/3*(sqrt(3)*t - sqrt(3))/(t - 1)^3]
# [24*c*t - 1/3*(sqrt(3)*t + sqrt(3))/(t^3 + 3*t^2 + 3*t + 1) - 3*(3*t + 1)/(3*t^2 + 2*t + 3)^(3/2) - 3*(3*t - 1)/(3*t^2 - 2*t + 3)^(3/2) + 1/3*(sqrt(3)*t - sqrt(3))/(t - 1)^3                                                                                                                               24*c*t - 1/24*(2*sqrt(3) + 9*sqrt(2) + 18)/t^2]

# %%
# Obtain the simplified expression
p1 = simplify_expression(C1.det())

# %%
show(C1.det().numerator().collect(c).combine())
# Out:
# 36*sqrt(3)*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 + 15552*(3*t^2 + 2*t + 3)^3*t^12 - 15552*(3*t^2 - 2*t + 3)^3*t^12 + 72*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 + 324*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 + 498*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 - 3456*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^9 - 3456*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^9 - 51840*(3*t^2 + 2*t + 3)^3*t^11 - 82944*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^(3/2)*t^11 - 51840*(3*t^2 - 2*t + 3)^3*t^11 - 144*sqrt(3)*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^6 - 1152*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^8 + 1152*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^8 - 46656*(3*t^2 + 2*t + 3)^3*t^10 + 46656*(3*t^2 - 2*t + 3)^3*t^10 - 288*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^6 - 1296*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^6 - 1992*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^6 + 10368*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^7 + 10368*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^7 + 207360*(3*t^2 + 2*t + 3)^3*t^9 + 331776*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^(3/2)*t^9 + 207360*(3*t^2 - 2*t + 3)^3*t^9 + 216*sqrt(3)*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^4 + 1536*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^5 + 3456*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^6 - 3456*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^6 + 31104*(3*t^2 + 2*t + 3)^3*t^8 - 31104*(3*t^2 - 2*t + 3)^3*t^8 + 432*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^4 + 1944*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^4 + 2988*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^4 - 10368*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^5 - 10368*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^5 - 311040*(3*t^2 + 2*t + 3)^3*t^7 - 497664*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^(3/2)*t^7 - 311040*(3*t^2 - 2*t + 3)^3*t^7 - 144*sqrt(3)*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^2 + 1536*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^3 - 3456*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^4 + 3456*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^4 + 31104*(3*t^2 + 2*t + 3)^3*t^6 - 31104*(3*t^2 - 2*t + 3)^3*t^6 - 288*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^2 - 1296*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^2 - 1992*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^2 + 3456*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^3 + 3456*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^3 + 207360*(3*t^2 + 2*t + 3)^3*t^5 + 331776*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^(3/2)*t^5 + 207360*(3*t^2 - 2*t + 3)^3*t^5 + 36*sqrt(3)*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3 + 1152*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^2 - 1152*sqrt(3)*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^2 - 46656*(3*t^2 + 2*t + 3)^3*t^4 + 46656*(3*t^2 - 2*t + 3)^3*t^4 + 72*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3 + 324*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3 + 498*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3 - 51840*(3*t^2 + 2*t + 3)^3*t^3 - 82944*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^(3/2)*t^3 - 51840*(3*t^2 - 2*t + 3)^3*t^3 + 15552*(3*t^2 + 2*t + 3)^3*t^2 - 15552*(3*t^2 - 2*t + 3)^3*t^2 - 576*(2*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^11 + 9*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^11 + 18*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^11 + 72*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^12 - 72*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^12 - 24*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^9 - 36*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^9 - 432*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^11 - 432*(3*t^2 + 2*t + 3)^(3/2)*(3*t^2 - 2*t + 3)^3*t^11 - 72*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^9 + 2*sqrt(3)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 + 9*sqrt(2)*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^3*t^8 - 216*(3*t^2 + 2*t + 3)^3*(3*t^2 - 2*t + 3)^(3/2)*t^10 + 216 ...

# %%
# checks if p1 was modified after simplification
print(bool(p1==C1.det()))
# Out:
# True

# %%
t, u, v = var('t, u, v')
assume(u>0); assume(v>0)

# %%
γ0 = p1.coefficients()[0][0]
γ1 = p1.coefficients()[1][0]

q1 = 3*t^2 + 2*t + 3 #u
q2 = 3*t^2 - 2*t + 3 #v

# %% [markdown]
# #### 3. $(C_1)_{11}(c(t),t)$ is positive for  $t$ in $(0,1)$.

# %%
C11 = C1[0,0].subs(c = -γ0/γ1)
C11_numerator = C11.numerator().simplify_real()

# %%
var('u,v')
assume(u>0)
assume(v>0)
C11_uvt_numerator = C11_numerator.subs({q2:v^2}).subs({q1:q1^2}).simplify_real().combine()

# %%
C11_uvt_numerator_factor = C11_uvt_numerator.simplify_full().expand().factor()

# %%
show(C11_uvt_numerator_factor)
# Out:
# -6*(4374*sqrt(3)*sqrt(2)*t^21*u^3*v^3 + 8748*sqrt(3)*t^21*u^3*v^3 + 39366*sqrt(2)*t^21*u^3*v^3 + 60507*t^21*u^3*v^3 - 14580*sqrt(3)*sqrt(2)*t^19*u^3*v^3 + 17496*sqrt(3)*t^22*u^3 + 78732*sqrt(2)*t^22*u^3 - 17496*sqrt(3)*t^22*v^3 - 78732*sqrt(2)*t^22*v^3 - 29160*sqrt(3)*t^19*u^3*v^3 + 26244*sqrt(2)*t^19*u^3*v^3 + 157464*t^22*u^3 - 157464*t^22*v^3 + 28674*t^19*u^3*v^3 - 104976*sqrt(3)*t^21*u^3 - 472392*sqrt(2)*t^21*u^3 - 104976*sqrt(3)*t^21*v^3 - 472392*sqrt(2)*t^21*v^3 - 944784*t^21*u^3 - 944784*t^21*v^3 - 39690*sqrt(3)*sqrt(2)*t^17*u^3*v^3 + 29160*sqrt(3)*t^20*u^3 + 131220*sqrt(2)*t^20*u^3 - 29160*sqrt(3)*t^20*v^3 - 131220*sqrt(2)*t^20*v^3 - 79380*sqrt(3)*t^17*u^3*v^3 - 94770*sqrt(2)*t^17*u^3*v^3 + 262440*t^20*u^3 - 262440*t^20*v^3 - 165105*t^17*u^3*v^3 - 69984*sqrt(3)*t^19*u^3 - 314928*sqrt(2)*t^19*u^3 + 139968*sqrt(3)*t^17*u^3*v^2 - 69984*sqrt(3)*t^19*v^3 - 314928*sqrt(2)*t^19*v^3 + 139968*sqrt(3)*t^17*u^2*v^3 - 629856*t^19*u^3 - 629856*t^19*v^3 - 4272*sqrt(3)*sqrt(2)*t^15*u^3*v^3 - 30456*sqrt(3)*t^18*u^3 - 137052*sqrt(2)*t^18*u^3 + 139968*sqrt(3)*t^16*u^3*v^2 + 30456*sqrt(3)*t^18*v^3 + 137052*sqrt(2)*t^18*v^3 - 139968*sqrt(3)*t^16*u^2*v^3 - 8544*sqrt(3)*t^15*u^3*v^3 - 155088*sqrt(2)*t^15*u^3*v^3 - 274104*t^18*u^3 + 1119744*t^17*u^2*v^2 + 274104*t^18*v^3 - 229736*t^15*u^3*v^3 + 252720*sqrt(3)*t^17*u^3 + 1137240*sqrt(2)*t^17*u^3 + 186624*sqrt(3)*t^15*u^3*v^2 + 252720*sqrt(3)*t^17*v^3 + 1137240*sqrt(2)*t^17*v^3 + 186624*sqrt(3)*t^15*u^2*v^3 + 2274480*t^17*u^3 + 2274480*t^17*v^3 + 89580*sqrt(3)*sqrt(2)*t^13*u^3*v^3 - 111048*sqrt(3)*t^16*u^3 - 499716*sqrt(2)*t^16*u^3 + 62208*sqrt(3)*t^14*u^3*v^2 + 111048*sqrt(3)*t^16*v^3 + 499716*sqrt(2)*t^16*v^3 - 62208*sqrt(3)*t^14*u^2*v^3 + 179160*sqrt(3)*t^13*u^3*v^3 + 69228*sqrt(2)*t^13*u^3*v^3 - 999432*t^16*u^3 - 995328*t^15*u^2*v^2 + 999432*t^16*v^3 - 502554*t^13*u^3*v^3 + 413568*sqrt(3)*t^15*u^3 + 1861056*sqrt(2)*t^15*u^3 - 248832*sqrt(3)*t^13*u^3*v^2 + 413568*sqrt(3)*t^15*v^3 + 1861056*sqrt(2)*t^15*v^3 - 248832*sqrt(3)*t^13*u^2*v^3 + 3722112*t^15*u^3 + 3722112*t^15*v^3 + 76680*sqrt(3)*sqrt(2)*t^11*u^3*v^3 - 38160*sqrt(3)*t^14*u^3 - 171720*sqrt(2)*t^14*u^3 - 262656*sqrt(3)*t^12*u^3*v^2 + 38160*sqrt(3)*t^14*v^3 + 171720*sqrt(2)*t^14*v^3 + 262656*sqrt(3)*t^12*u^2*v^3 + 153360*sqrt(3)*t^11*u^3*v^3 + 230040*sqrt(2)*t^11*u^3*v^3 - 343440*t^14*u^3 - 2267136*t^13*u^2*v^2 + 343440*t^14*v^3 - 4699572*t^11*u^3*v^3 - 184608*sqrt(3)*t^13*u^3 - 830736*sqrt(2)*t^13*u^3 - 581376*sqrt(3)*t^11*u^3*v^2 - 184608*sqrt(3)*t^13*v^3 - 830736*sqrt(2)*t^13*v^3 - 581376*sqrt(3)*t^11*u^2*v^3 - 1661472*t^13*u^3 - 1661472*t^13*v^3 - 43428*sqrt(3)*sqrt(2)*t^9*u^3*v^3 + 133008*sqrt(3)*t^12*u^3 + 598536*sqrt(2)*t^12*u^3 - 343296*sqrt(3)*t^10*u^3*v^2 - 133008*sqrt(3)*t^12*v^3 - 598536*sqrt(2)*t^12*v^3 + 343296*sqrt(3)*t^10*u^2*v^3 - 86856*sqrt(3)*t^9*u^3*v^3 + 69228*sqrt(2)*t^9*u^3*v^3 + 1197072*t^12*u^3 + 110592*t^11*u^2*v^2 - 1197072*t^12*v^3 - 2565498*t^9*u^3*v^3 - 613440*sqrt(3)*t^11*u^3 - 2760480*sqrt(2)*t^11*u^3 - 56448*sqrt(3)*t^9*u^3*v^2 - 613440*sqrt(3)*t^11*v^3 - 2760480*sqrt(2)*t^11*v^3 - 56448*sqrt(3)*t^9*u^2*v^3 - 5520960*t^11*u^3 - 5520960*t^11*v^3 - 99120*sqrt(3)*sqrt(2)*t^7*u^3*v^3 + 133008*sqrt(3)*t^10*u^3 + 598536*sqrt(2)*t^10*u^3 + 169344*sqrt(3)*t^8*u^3*v^2 - 133008*sqrt(3)*t^10*v^3 - 598536*sqrt(2)*t^10*v^3 - 169344*sqrt(3)*t^8*u^2*v^3 - 198240*sqrt(3)*t^7*u^3*v^3 - 155088*sqrt(2)*t^7*u^3*v^3 + 1197072*t^10*u^3 + 4064256*t^9*u^2*v^2 - 1197072*t^10*v^3 - 2930792*t^7*u^3*v^3 - 184608*sqrt(3)*t^9*u^3 - 830736*sqrt(2)*t^9*u^3 + 578304*sqrt(3)*t^7*u^3*v^2 - 184608*sqrt(3)*t^9*v^3 - 830736*sqrt(2)*t^9*v^3 + 578304*sqrt(3)*t^7*u^2*v^3 - 1661472*t^9*u^3 - 1661472*t^9*v^3 - 23490*sqrt(3)*sqrt(2)*t^5*u^3*v^3 - 38160*sqrt(3)*t^8*u^3 - 171720*sqrt(2)*t^8*u^3 + 352512*sqrt(3)*t^6*u^3*v^2 + 38160*sqrt(3)*t^8*v^3 + 171720*sqrt(2)*t^8*v^3 - 352512*sqrt(3)*t^6*u^2*v^3 - 46980*sqrt(3)*t^5*u^3*v^3 - 94770*sqrt(2)*t^5*u^3*v^3 - 343440*t^8*u^3 + 110592*t^7*u^2*v^2 + 343440*t^8*v^3 - 5241537*t^5*u^3*v^3 + 413568*sqrt(3)*t ...

# %%
c11_uv = C11_uvt_numerator_factor.subs(t=0)

# %%
show(c11_uv.factor())
# Out:
# 17496*(16*sqrt(3)*u^2*v^2 - 6*sqrt(3)*u^2 - 27*sqrt(2)*u^2 - 6*sqrt(3)*u*v - 27*sqrt(2)*u*v - 6*sqrt(3)*v^2 - 27*sqrt(2)*v^2 - 54*u^2 - 54*u*v - 54*v^2)*(u - v)*u*v

# %%
C11_denominator = C11.denominator().subs({q2:v^2}).subs({q1:u^2}).simplify_real().combine()

# %%
show(C11_denominator.expand().subs(t=0))
# Out:
# 34992*sqrt(3)*u^4*v^4 + 157464*sqrt(2)*u^4*v^4 + 314928*u^4*v^4

# %% [markdown]
# ##### Calculates the Möbius coefficient

# %%
coefficient_dict = polynomial_to_dict(C11_uvt_numerator)

# %%
variables = C11_uvt_numerator.variables()
total_degree  =  [C11_uvt_numerator.degree(j) for j in variables]
n_uplas = [
    [i, j, k]
    for i in range(total_degree[0] + 1)
    for j in range(total_degree[1] + 1)
    for k in range(total_degree[2] + 1)
]

# %%
#variable_ranges_2 = [ (1/8, 1), (u0, u1), (v0, v1)]
#variable_ranges_1 = [ (1/64, 1/8), (u0, u1), (v0, v1)]
#variable_ranges_0 = [ (0, 1/64), (u0, u1), (v0, v1)]
#all_variable_ranges_3 = [variable_ranges_1]




# Calculate the values of u and v for t = 0 and t = 1/2
(u0, u1) = quadratic_extrema_on_interval(q1, (1/16, 1/4))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/16, 1/4))
variable_ranges_0 = [(1/16, 1/4), (u0, u1), (v0, v1)]

# Calculate the values of u and v for t = 1/4 and t = 1/2
(u0, u1) = quadratic_extrema_on_interval(q1, (1/4, 1/2))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/4, 1/2))
variable_ranges_1 = [(1/4, 1/2), (u0, u1), (v0, v1)]

# Calculate the values of u and  for t = 1/2 and t = 1
(u0, u1) = quadratic_extrema_on_interval(q1, (1/2, 1))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/2, 1) )
variable_ranges_2 = [ (1/2, 1), (u0, u1), (v0, v1)]


all_variable_ranges = [variable_ranges_0 ]

# %%
plot([q1, q2])

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()

for variable_ranges in all_variable_ranges:
    sign_coeff_set = set()
    for i, degree_per_variable in enumerate(n_uplas):
        
        c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
    
        if i % 100 == 0:
            elapsed_time = time.time() - start_time
            elapsed_time_minutes = elapsed_time / 60
            print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
            print("Conjunto parcial de coeficientes:", sign_coeff_set)  
            print("\n")
        
        
        if c.is_zero():         
             continue
    
        else:
            sign_coeff = sign(c.simplify_full())
            sign_coeff_set.add(sign_coeff)
    
        if 1 in sign_coeff_set and -1 in sign_coeff_set:
            
            print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
            break
            
        
    print("Conjunto final de coeficientes para t em {}: {}.".format(variable_ranges[0], sign_coeff_set) )

# %%
uu = q1(t=0)
vv= q2(t=0)
print(uu)
print(vv)
c11_uv.subs(u=uu)
# Out:
# 3
# 3
# -7243344*sqrt(3)*v^4 + 1417176*sqrt(2)*v^4 + 2834352*v^4 + 22674816*sqrt(3)*v^3 - 8503056*sqrt(3)*v - 38263752*sqrt(2)*v - 76527504*v

# %%
variables = C11_uvt_numerator.variables()
total_degree  =  [C11_uvt_numerator.degree(j) for j in variables]
n_uplas = [
    [i, j, k]
    for i in range(total_degree[0] + 1)
    for j in range(total_degree[1] + 1)
    for k in range(total_degree[2] + 1)
]

# %%
#variable_ranges_2 = [ (1/8, 1), (u0, u1), (v0, v1)]
#variable_ranges_1 = [ (1/64, 1/8), (u0, u1), (v0, v1)]
#variable_ranges_0 = [ (0, 1/64), (u0, u1), (v0, v1)]
#all_variable_ranges_3 = [variable_ranges_1]


q1 = 3*t^2 + 2*t + 3 #u
q2 = 3*t^2 - 2*t + 3 #v

# Calculate the values of u and v for t = 0 and t = 1/2
(u0, u1) = quadratic_extrema_on_interval(q1, (1/16, 1/4))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/16, 1/4))
variable_ranges_0 = [(1/16, 1/4), (u0, u1), (v0, v1)]

# Calculate the values of u and v for t = 1/4 and t = 1/2
(u0, u1) = quadratic_extrema_on_interval(q1, (1/4, 1/2))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/4, 1/2))
variable_ranges_1 = [(1/4, 1/2), (u0, u1), (v0, v1)]

# Calculate the values of u and  for t = 1/2 and t = 1
(u0, u1) = quadratic_extrema_on_interval(q1, (1/2, 1))
(v0, v1) = quadratic_extrema_on_interval(q2, (1/2, 1) )
variable_ranges_2 = [ (1/2, 1), (u0, u1), (v0, v1)]


all_variable_ranges = [variable_ranges_0 ]

# %%
plot([q1, q2])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()

for variable_ranges in all_variable_ranges:
    sign_coeff_set = set()
    for i, degree_per_variable in enumerate(n_uplas):
        
        c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
    
        if i % 100 == 0:
            elapsed_time = time.time() - start_time
            elapsed_time_minutes = elapsed_time / 60
            print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
            print("Conjunto parcial de coeficientes:", sign_coeff_set)  
            print("\n")
        
        
        if c.is_zero():         
             continue
    
        else:
            sign_coeff = sign(c.simplify_full())
            sign_coeff_set.add(sign_coeff)
    
        if 1 in sign_coeff_set and -1 in sign_coeff_set:
            
            print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
            break
            
        
    print("Conjunto final de coeficientes para t em {}: {}.".format(variable_ranges[0], sign_coeff_set) )
# Out:
# Iteração: 0, Tempo decorrido: 0.00 minutos
# Conjunto parcial de coeficientes: set()
#
#
# Iteração: 100, Tempo decorrido: 0.21 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 200, Tempo decorrido: 0.41 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 300, Tempo decorrido: 0.62 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 400, Tempo decorrido: 0.89 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 500, Tempo decorrido: 1.16 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 600, Tempo decorrido: 1.43 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Conjunto final de coeficientes para t em (1/16, 1/4): {1}.

# %%
uu = q1(t=0)
vv= q2(t=0)
C11_uvt_numerator.subs(t=0, u=uu, v=vv)
# Out:
# 0

# %%
# coeff = []
# for i, degree_per_variable in enumerate(n_uplas):
    
#     c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
#     coeff.append(c)

# %%
variable_ranges_2 = [ (1/8, 1), (u0, u1), (v0, v1)]
variable_ranges_1 = [ (1/64, 1/8), (u0, u1), (v0, v1)]
variable_ranges_0 = [ (0, 1/64), (u0, u1), (v0, v1)]
all_variable_ranges_3 = [variable_ranges_1]

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()

for variable_ranges in all_variable_ranges_3:
    sign_coeff_set = set()
    for i, degree_per_variable in enumerate(n_uplas):
        
        c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
    
        # if i % 1000 == 0:
        #     elapsed_time = time.time() - start_time
        #     elapsed_time_minutes = elapsed_time / 60
        #     print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
        #     print("Conjunto parcial de coeficientes:", sign_coeff_set)  
        #     print("\n")
        
        
        if c.is_zero():         
             continue
    
        else:
            sign_coeff = sign(c.simplify_full())
            sign_coeff_set.add(sign_coeff)
    
        if 1 in sign_coeff_set and -1 in sign_coeff_set:
            
            print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
            break
            
        
    print("Conjunto final de coeficientes para t em {}: {}.".format(variable_ranges[0], sign_coeff_set) )

# %%
# coeff = []
# for i, degree_per_variable in enumerate(n_uplas):
    
#     c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
#     coeff.append(c)

# %%
variable_ranges_2 = [ (1/64, 1/32), (u0, u1), (v0, v1)]
variable_ranges_1 = [ (1/4, 3/4), (u0, u1), (v0, v1)]
variable_ranges_0 = [ (0, 1/64), (u0, u1), (v0, v1)]
all_variable_ranges_3 = [variable_ranges_0, variable_ranges_1, variable_ranges_2]

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()
sign_coeff_set = set()
for variable_ranges in all_variable_ranges_3:
    for i, degree_per_variable in enumerate(n_uplas):
        
        c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
    
        # if i % 1000 == 0:
        #     elapsed_time = time.time() - start_time
        #     elapsed_time_minutes = elapsed_time / 60
        #     print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
        #     print("Conjunto parcial de coeficientes:", sign_coeff_set)  
        #     print("\n")
        
        
        if c.is_zero():         
             continue
    
        else:
            sign_coeff = sign(c.simplify_full())
            sign_coeff_set.add(sign_coeff)
    
        if 1 in sign_coeff_set and -1 in sign_coeff_set:
            
            print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
            break
            
        
    print("Conjunto final de coeficientes para t em {}: {}.".format(variable_ranges[0], sign_coeff_set) )

# %%
# coeff = []
# for i, degree_per_variable in enumerate(n_uplas):
    
#     c = moebius_coefficient(C11_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
#     coeff.append(c)

# %% [markdown]
# #####  Checking the sign of Möbius coefficients

# %%
coefficient_signs = set([sign(c) for c in coeff])

# %%
set(coefficient_signs)

# %% [markdown]
# ##### Limit at the extremes

# %%
limit(C11, t=0, dir='+'), limit(C11, t=1, dir='-')

# %% [markdown]
# ##### 5. There exits a $\delta<1$ such $(O_1)_{12}(c(t),t)$ is negative for $t$ in $(0,\delta)$ and is positive for $t$ in $(\delta,1)$ .

# %%
C12 = C1[0,1].subs(c = -γ0/γ1)
C12_diff = diff(C12, t) # derivative

# %%
C12_diff_numerator = C12_diff.numerator().simplify_real().expand().combine()

# %%
C12_diff_numerator_uvt = C12_diff_numerator.subs({(3*t^2 - 2*t + 3):v^2}).subs({(3*t^2 + 2*t + 3):u^2}).simplify_real().expand().combine()

# %% [markdown]
# ##### Calculates the Möbius coefficient

# %%
coefficient_dict = polynomial_to_dict(C12_diff_numerator_uvt)

# %%
variables = C12_diff_numerator_uvt.variables()
total_degree  =  [C12_diff_numerator_uvt.degree(j) for j in variables]
n_uplas = [
    [i, j, k]
    for i in range(total_degree[0] + 1)
    for j in range(total_degree[1] + 1)
    for k in range(total_degree[2] + 1)
]
len(n_uplas)

# %%
# coeff = []
# for i, degree_per_variable in enumerate(n_uplas):    
#     c = moebius_coefficient(C12_diff_numerator_uvt, degree_per_variable, total_degree, variable_ranges, coefficient_dict)
#     coeff.append(c)

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()
sign_coeff_set = set()
variable_ranges = [(0, 1), (u0, u1), (v0, v1)]
for i, degree_per_variable in enumerate(n_uplas):
    
    c = moebius_coefficient(C12_diff_numerator_uvt, degree_per_variable, total_degree, variable_ranges, coefficient_dict)

    if i % 1000 == 0:
        elapsed_time = time.time() - start_time
        elapsed_time_minutes = elapsed_time / 60
        print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
        print("Conjunto parcial de coeficientes:", sign_coeff_set)  
        print("\n")
    
    
    if c.is_zero():         
         continue

    else:
        sign_coeff = sign(c.simplify_full())
        sign_coeff_set.add(sign_coeff)

    if 1 in sign_coeff_set and -1 in sign_coeff_set:
        
        print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
        break
        
    
print("Conjunto final de coeficientes:", sign_coeff_set)

# %%
import time

# Inicialize a lista de coeficientes

# Capture o tempo de início
start_time = time.time()
sign_coeff_set = set()

for i, degree_per_variable in enumerate(n_uplas):
    
    c = moebius_coefficient(C12_diff_numerator_uvt, degree_per_variable, total_degree, variable_ranges, coefficient_dict)

    if i % 100 == 0:
        elapsed_time = time.time() - start_time
        elapsed_time_minutes = elapsed_time / 60
        print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
        print("Conjunto parcial de coeficientes:", sign_coeff_set)  
        print("\n")
    
    
    if c.is_zero():         
         continue

    else:
        sign_coeff = sign(c.simplify_full())
        sign_coeff_set.add(sign_coeff)

    if 1 in sign_coeff_set and -1 in sign_coeff_set:
        
        print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
        break
        
    
print("Conjunto final de coeficientes:", sign_coeff_set)

# %% [markdown]
# #####  Checking the sign of Möbius coefficients

# %%
coefficient_signs = set([sign(c) for c in coeff])

# %%
set(coefficient_signs)

# %% [markdown]
# ##### Limit at the extremes

# %%
bool(limit(C12, t=0, dir='+')< 0), bool(limit(C11, t=1, dir='-') > 0)
