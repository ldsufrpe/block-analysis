# %% [markdown]
# ## Analyzing the block C Truncated Tetrahedra

# %%
load("../util.sage")

# %%
blocks = load("blocks")

# %%
C = blocks.matrix_from_rows_and_columns([3],[3]); 
p1 = C.det().simplify_real().expand().combine()

# %%
show(p1)
# Out:
# -1/64*t/(t^6 - 6*t^5 + 15*t^4 - 20*t^3 + 15*t^2 - 6*t + 1) + 1/64/(4*t^2 - 4*t + 1)^2 - 3/32*(4*sqrt(2)*t^2 - 4*sqrt(2)*t + sqrt(2))/((6*t^2 - 6*t + 2)^(3/2)*(4*t^2 - 4*t + 1)^(3/2)) - 1/8*(4*t^2 - 4*t + 1)/((6*t^2 - 6*t + 2)^(3/2)*(4*t^2 - 4*t + 2)^(3/2)) + 1/128*(20*t^2 - 20*t + 7)/(3*t^2 - 3*t + 1)^3 + 1/64*(4*t^2 - 4*t + 1)/(2*t^2 - 2*t + 1)^3 + 1/128*(3*t^2 - 4*t + 3)/(t^2 - 2*t + 1)^3 - 1/32*(2*sqrt(2)*t^2 - 5*sqrt(2)*t + 3*sqrt(2))/((6*t^2 - 6*t + 2)^(3/2)*(t^2 - 2*t + 1)^(3/2)) - 1/32*(2*sqrt(2)*t^2 - 3*sqrt(2)*t + sqrt(2))/((4*t^2 - 4*t + 2)^(3/2)*(t^2 - 2*t + 1)^(3/2)) + 1/64*(2*t^2 - 3*t + 1)/((4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)) - 1/16*sqrt(2)/((6*t^2 - 6*t + 2)^(3/2)*t) - 1/16*sqrt(2)/((4*t^2 - 4*t + 2)^(3/2)*t) + 1/32/((4*t^2 - 4*t + 1)^(3/2)*t) - 1/64/((t^2 - 2*t + 1)^(3/2)*t) - 1/32*sqrt(2)/((6*t^2 - 6*t + 2)^(3/2)*t^2) + 1/32*sqrt(2)/((4*t^2 - 4*t + 2)^(3/2)*t^2) - 1/64/((4*t^2 - 4*t + 1)^(3/2)*t^2) + 1/64/((t^2 - 2*t + 1)^(3/2)*t^2) + 3/128/t^4

# %%
#p1_simplify = simplify_fractional_radicals(p1); show(p1_simplify)

# %%
p1_uvt_numerator = p1.subs({4*t^2 - 4*t + 2:u^2, 6*t^2 - 6*t + 2:v^2}).numerator(); show(p1_uvt_numerator)
# Out:
# 13824*(u^3*v^3 - 2*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 12*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 2*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 16*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^26 - 6912*(27*u^3*v^3 - 58*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 312*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 54*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 416*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^25 + 6912*(175*u^3*v^3 - 402*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 1950*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 350*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 2600*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^24 - 6912*((4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 2*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 4*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 4*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 725*u^3*v^3 - 1774*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 7800*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 1450*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 10400*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^23 + 288*(312*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 600*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 1104*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 1200*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 51739*u^3*v^3 - 134390*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 538068*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 103478*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 717424*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^22 - 144*(3888*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 7200*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 12096*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 14400*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 235037*u^3*v^3 - 646118*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 2365176*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 470074*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 3153568*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^21 + 16*(1699*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 139104*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 248400*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 377568*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 496800*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 3812882*u^3*v^3 - 11064232*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 37159998*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 7625764*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 49546664*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^20 - 8*(33980*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 792198*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 1365804*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 1857240*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 2731608*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 11184441*u^3*v^3 - 34181942*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 105647880*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 22368882*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 140863840*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^19 + 8*(167513*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 1719234*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 2864862*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 3435300*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 5729724*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 13575733*u^3*v^3 - 43613818*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 124367562*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 27151466*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 165823416*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^18 - 4*(1078374*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 5906530*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 9521804*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 9878584*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3 + 19043608*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*v^3 + 27589463*u^3*v^3 - 93019506*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*u^3 - 245247228*sqrt(2)*(t^2 - 2*t + 1)^(3/2)*u^3 - 55178926*sqrt(2)*(4*t^2 - 4*t + 1)^(3/2)*v^3 - 326996304*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2))*t^17 + 4*(2535293*(4*t^2 - 4*t + 1)^(3/2)*(t^2 - 2*t + 1)^(3/2)*u^3*v^3 + 8231176*(4*t^2 - 4*t + 1)^(3/2)*u^3*v^3 - 12847078*(t^2 - 2*t + 1)^(3/2)*u ...

# %%
p1_uvt_numerator = p1_uvt_numerator.canonicalize_radical().expand().combine(); show(p1_uvt_numerator)
# Out:
# -608256*sqrt(2)*t^29*u^3 - 442368*sqrt(2)*t^29*v^3 - 1769472*t^32 + 189824*t^26*u^3*v^3 + 9732096*sqrt(2)*t^28*u^3 + 7077888*sqrt(2)*t^28*v^3 + 30965760*t^31 - 2752448*t^25*u^3*v^3 - 74856960*sqrt(2)*t^27*u^3 - 54853632*sqrt(2)*t^27*v^3 - 261881856*t^30 + 19508768*t^24*u^3*v^3 + 368616960*sqrt(2)*t^26*u^3 + 274268160*sqrt(2)*t^26*v^3 + 1425752064*t^29 - 89964144*t^23*u^3*v^3 - 1305392256*sqrt(2)*t^25*u^3 - 994093056*sqrt(2)*t^25*v^3 - 5615345664*t^28 + 303061024*t^22*u^3*v^3 + 3539757312*sqrt(2)*t^24*u^3 + 2782015488*sqrt(2)*t^24*v^3 + 17044623360*t^27 - 793750760*t^21*u^3*v^3 - 7639383520*sqrt(2)*t^23*u^3 - 6251404288*sqrt(2)*t^23*v^3 - 41474756608*t^26 + 1679592648*t^20*u^3*v^3 + 13461721312*sqrt(2)*t^22*u^3 + 11579536384*sqrt(2)*t^22*v^3 + 83079430144*t^25 - 2945453692*t^19*u^3*v^3 - 19710679280*sqrt(2)*t^21*u^3 - 18010360512*sqrt(2)*t^21*v^3 - 139595262720*t^24 + 4356885332*t^18*u^3*v^3 + 24269929600*sqrt(2)*t^20*u^3 + 23837411584*sqrt(2)*t^20*v^3 + 199457373312*t^23 - 5503645044*t^17*u^3*v^3 - 25328197496*sqrt(2)*t^19*u^3 - 27108895680*sqrt(2)*t^19*v^3 - 244796650752*t^22 + 5988635580*t^16*u^3*v^3 + 22500620296*sqrt(2)*t^18*u^3 + 26675343808*sqrt(2)*t^18*v^3 + 259985008320*t^21 - 5645913156*t^15*u^3*v^3 - 17032033396*sqrt(2)*t^17*u^3 - 22821706592*sqrt(2)*t^17*v^3 - 240202919360*t^20 + 4628241028*t^14*u^3*v^3 + 10954648560*sqrt(2)*t^16*u^3 + 17027007744*sqrt(2)*t^16*v^3 + 193750215200*t^19 - 3304427768*t^13*u^3*v^3 - 5939068248*sqrt(2)*t^15*u^3 - 11094305760*sqrt(2)*t^15*v^3 - 136719965952*t^18 + 2054773678*t^12*u^3*v^3 + 2669202124*sqrt(2)*t^14*u^3 + 6312506368*sqrt(2)*t^14*v^3 + 84457484656*t^17 - 1110988405*t^11*u^3*v^3 - 960156592*sqrt(2)*t^13*u^3 - 3131563372*sqrt(2)*t^13*v^3 - 45642311104*t^16 + 520606381*t^10*u^3*v^3 + 252922160*sqrt(2)*t^12*u^3 + 1350221664*sqrt(2)*t^12*v^3 + 21534129408*t^15 - 210356630*t^9*u^3*v^3 - 33083400*sqrt(2)*t^11*u^3 - 503478780*sqrt(2)*t^11*v^3 - 8838366512*t^14 + 72764241*t^8*u^3*v^3 - 9265088*sqrt(2)*t^10*u^3 + 161215508*sqrt(2)*t^10*v^3 + 3139118672*t^13 - 21335461*t^7*u^3*v^3 + 7964608*sqrt(2)*t^9*u^3 - 43895944*sqrt(2)*t^9*v^3 - 957710496*t^12 + 5231962*t^6*u^3*v^3 - 3062536*sqrt(2)*t^8*u^3 + 10027836*sqrt(2)*t^8*v^3 + 248482576*t^11 - 1053317*t^5*u^3*v^3 + 808488*sqrt(2)*t^7*u^3 - 1886708*sqrt(2)*t^7*v^3 - 54085936*t^10 + 169585*t^4*u^3*v^3 - 156600*sqrt(2)*t^6*u^3 + 284768*sqrt(2)*t^6*v^3 + 9693504*t^9 - 20999*t^3*u^3*v^3 + 22172*sqrt(2)*t^5*u^3 - 33156*sqrt(2)*t^5*v^3 - 1393168*t^8 + 1878*t^2*u^3*v^3 - 2192*sqrt(2)*t^4*u^3 + 2796*sqrt(2)*t^4*v^3 + 154384*t^7 - 108*t*u^3*v^3 + 136*sqrt(2)*t^3*u^3 - 152*sqrt(2)*t^3*v^3 - 12384*t^6 + 3*u^3*v^3 - 4*sqrt(2)*t^2*u^3 + 4*sqrt(2)*t^2*v^3 + 640*t^5 - 16*t^4

# %%
# Calculate the values of u for t = 0 and t = 1

# Solve 3*t^2 + 2*t + 3 = u^2 for u}
sol_u = solve(u**2 == 4*t^2 - 4*t + 2, u)[0].rhs()

# Solve 3*t^2 - 2*t + 3 = v^2 for v
sol_v = solve(v**2 == 6*t^2 - 6*t + 2, v)[0].rhs()

# Get the values of u for t=0 and t=1
u0 = sol_u(t=0)
u1 = sol_u(t=1/2)

# Get the values of v for t=1/3 and t=1
v0 = sol_v(t=0)
v1 = sol_v(t=1/2)

u0, u1, v0, v1
# Out:
# (sqrt(2), 1, sqrt(2), sqrt(1/2))

# %%
variable_ranges = [(0, 1/2), (u0, u1), (v0, v1)]

# %% [markdown]
# ##### Calculates the Möbius coefficient

# %%
coefficient_dict = polynomial_to_dict(p1_uvt_numerator)

# %%
variables = p1_uvt_numerator.variables()
total_degree  =  [p1_uvt_numerator.degree(j) for j in variables]
n_uplas = [
    [i, j, k]
    for i in range(total_degree[0] + 1)
    for j in range(total_degree[1] + 1)
    for k in range(total_degree[2] + 1)
]

# %%
print(variables)
# Out:
# (t, u, v)

# %%
import time


# Capture o tempo de início
start_time = time.time()
sign_coeff_set = set()

for i, degree_per_variable in enumerate(n_uplas):
    
    c = moebius_coefficient(p1_uvt_numerator, degree_per_variable, total_degree, variable_ranges, coefficient_dict)

    if i % 100 == 0:
        elapsed_time = time.time() - start_time
        elapsed_time_minutes = elapsed_time / 60
        print(f"Iteração: {i}, Tempo decorrido: {elapsed_time_minutes:.2f} minutos")
        print("Conjunto parcial de coeficientes:", sign_coeff_set)  
        print("\n")
    
    
    if c.is_zero():         
         continue

    else:
        sign_coeff = sign(c.simplify_full())
        sign_coeff_set.add(sign_coeff)

    if 1 in sign_coeff_set and -1 in sign_coeff_set:
        
        print(f"Encerrando na iteração {i} pois o conjunto contém 1 e -1.")
        break
        
    
print("Conjunto final de coeficientes:", sign_coeff_set)
# Out:
# Iteração: 0, Tempo decorrido: 0.00 minutos
# Conjunto parcial de coeficientes: set()
#
#
# Iteração: 100, Tempo decorrido: 0.12 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 200, Tempo decorrido: 0.25 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 300, Tempo decorrido: 0.39 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 400, Tempo decorrido: 0.52 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Iteração: 500, Tempo decorrido: 0.67 minutos
# Conjunto parcial de coeficientes: {1}
#
#
# Conjunto final de coeficientes: {1}

# %% [markdown]
# ##### Limit at the extremes

# %%
bool(limit(p1, t=0, dir='+')> 0) # left
# Out:
# True

# %%
bool(limit(p1, t=1/2, dir='-') > 0) # right
# Out:
# True

# %%
plot(p1, (t, 0, 0.97), ymax=200)
# Out:
# Graphics object consisting of 1 graphics primitive
